# %% [markdown]
# # Kunskapskontroll 1 – Statistik och Dataanalys

# %% [markdown]
# ## **Del 1 – Teoretiska frågor**

# %% [markdown]
# ### **1. Finns det ett samband mellan antalet storkar och antalet födslar?**
# Nej, det finns inget orsakssamband mellan storkar och barnafödsel. Detta är ett exempel på **korrelation**, men inte **kausalitet**.
#
# - **Korrelation** betyder att två saker händer samtidigt.
# - **Kausalitet** betyder att en sak orsakar en annan.
#
# I detta fall är det troligt att både antalet storkar och födslar är vanligare på landsbygden, vilket gör att de verkar ha ett samband – men storkar orsakar inte födslar.

# %% [markdown]
# ### **2: Vad är korrelation?**
#
# Korrelation betyder att två saker förändras tillsammans, men det betyder inte att den ena orsakar den andra.
#
# #### **Exempel 1: Glassförsäljning och drunkningsolyckor**
# - När glassförsäljningen ökar, ökar också antalet drunkningsolyckor.
# - Detta betyder inte att glass orsakar drunkning.
# - Båda ökar eftersom det är varmt på sommaren (**en tredje faktor påverkar båda**).
#
# #### **Exempel 2: Längd och skostorlek**
# - Personer med större skostorlek är ofta längre.
# - Här finns en **korrelation**, men det betyder inte att stora fötter gör dig längre – båda påverkas av din kropps tillväxt.
#
# #### **Typer av korrelation**
# - **Positiv korrelation**: När en variabel ökar, ökar även den andra.
#   - Exempel: Ju mer du tränar, desto bättre kondition får du.
# - **Negativ korrelation**: När en variabel ökar, minskar den andra.
#   - Exempel: Ju mer tid du spenderar på sociala medier, desto mindre tid har du för studier.
#
# **Viktigt:** Korrelation betyder inte **kausalitet** (orsakssamband).

# %% [markdown]
# ### **3. Är medelvärde bättre än median?**
# Det beror på situationen!
#
# - **Medelvärde** (genomsnitt) är känsligt för extremvärden.
# - **Median** (mittenvärdet) påverkas inte av extremvärden.
#
# Exempel:
# Om vi har dessa löner: **25 000, 26 000, 27 000, 28 000, 1 000 000 kr**
# - **Medelvärde:** (25 000 + 26 000 + 27 000 + 28 000 + 1 000 000) ÷ 5 = **221 200 kr**
# - **Median:** **27 000 kr** (mittenvärdet)
#
# Här ger medianen en mer rättvis bild av lönerna.

# %% [markdown]
# ### **4. Vad används cirkeldiagram till?**
# Cirkeldiagram visar **andelar av en helhet**.
#
# Exempel:
# Spotify kan använda ett cirkeldiagram för att visa **musikgenrer** som lyssnas på:
# - **Pop: 40%**
# - **Rock: 30%**
# - **Hip-hop: 20%**
# - **Jazz: 10%**
#
# Cirkeldiagram fungerar bäst när summan är 100%.

# %% [markdown]
# ### **5. Vad används linjediagram till?**
# Linjediagram visar **förändring över tid**.
#
# Exempel:
# Spotify kan använda ett linjediagram för att visa hur många som lyssnar på en viss artist **varje månad**.
#
# Om lyssningar på en artist ökar över tid, kan Spotify använda den informationen för att marknadsföra den artisten mer.

# %% [markdown]
# ### **6. Vad används lådagram till?**
# Lådagram (boxplot) visar **spridning och extremvärden** i data.
#
# Ett lådagram visar:
# - **Medianen** (mittenvärdet)
# - **Övre och undre kvartiler** (25% och 75% av datan)
# - **Extremvärden** (ovanligt höga/låga värden)
#
# Exempel:
# Om vi analyserar löner på ett företag kan ett lådagram visa om vissa anställda har mycket högre eller lägre lön än resten.

# %% [markdown]
# ### **7. Vad betyder att nyföddas vikt är normalfördelad?**
#
# Normalfördelning betyder att de flesta värden ligger nära medelvärdet, och att väldigt höga eller låga värden är ovanliga.
#
# #### **Information om nyföddas vikt i Sverige:**
# - **Medelvikt** = 3.5 kg
# - **Standardavvikelse** = 0.5 kg
#
# #### **Normalfördelning och sannolikhet:**
# - **68% av alla nyfödda barn** väger mellan **3.0 kg och 4.0 kg**.
# - **95% av alla nyfödda barn** väger mellan **2.5 kg och 4.5 kg**.
# - **Endast 2.3% av barnen** väger **mer än 4.5 kg**.
#
# #### **Hur många barn väger över 4.5 kg?**
# - Vi vet att **2.3% av barnen väger över 4.5 kg**.
# - Om vi tittar på **1000 nyfödda barn**:
#   \[
#   1000 \times 0.023 = 23
#   \]
#   **Svar:** **Cirka 23 barn väger över 4.5 kg.**

# %% [markdown]
# ## Del 2 – Statistisk dataanalys i Python

# %%
### Kunskapskontroll 1 – Statistik och Dataanalys

# 🔹 Importera bibliotek
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl

# %% [markdown]
# ### Läs in data

# %%
df = pd.read_excel("HR_Employee_Data.xlsx", engine="openpyxl")

# %% [markdown]
# ### Dataförberedelse

# %%
# 1. Korrigera datatyper för kategoriska kolumner
df["salary"] = df["salary"].astype("category")
df["Department"] = df["Department"].astype("category")

# 2. Omvandla binära variabler (0/1) till kategoriska för lättare tolkning
df["Work_accident"] = df["Work_accident"].map({0: "No", 1: "Yes"})
df["left"] = df["left"].map({0: "Stayed", 1: "Left"})
df["promotion_last_5years"] = df["promotion_last_5years"].map({0: "No", 1: "Yes"})

# 3. Skala om vissa värden för bättre läsbarhet
# satisfaction_level
df['satisfaction_level'] = (df['satisfaction_level'] * 100).astype(int)
# last_evaluation
df["last_evaluation"] = df["last_evaluation"] * 100

# %% [markdown]
# ### Beskrivande statistik

# %%
print(df.describe(include="all"))
# Out:
#           Emp_Id  satisfaction_level  last_evaluation  number_project  \
# count      14999        14999.000000     14999.000000    14999.000000
# unique     14999                 NaN              NaN             NaN
# top     IND11649                 NaN              NaN             NaN
# freq           1                 NaN              NaN             NaN
# mean         NaN         6125.468365        71.610174        3.803054
# std          NaN         2487.092846        17.116911        1.232592
# min          NaN          900.000000        36.000000        2.000000
# 25%          NaN         4400.000000        56.000000        3.000000
# 50%          NaN         6400.000000        72.000000        4.000000
# 75%          NaN         8200.000000        87.000000        5.000000
# max          NaN        10000.000000       100.000000        7.000000
#
#         average_montly_hours  time_spend_company Work_accident left  \
# ...

# %% [markdown]
# - **Sammanfattning**
#
# - Antal anställda: 14 999, flest inom sales (4 140 personer).
#
# - Arbetstillfredsställelse: Medelvärde 61.2 (skala 0-100).
#
# - Senaste utvärdering: Snitt 71.6.
#
# - Projekt: I snitt 3.8 projekt per person, max 7.
#
# - Arbetstid: Snitt 201 timmar/månad, max 310.
#
# - Anställningstid: Snitt 3.5 år, max 10 år.
#
# - Befordringar: Inga senaste 5 åren.
#
# - Löner: De flesta har låg lön.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["satisfaction_level"], bins=30, kde=True, color="blue")
plt.xlabel("Tillfredsställelsenivå")
plt.ylabel("Antal anställda")
plt.title("Fördelning av tillfredsställelse")
plt.show()

# %% [markdown]
# ### **Kort analys:**
# - **Två toppar:** Många anställda är antingen **mycket missnöjda (0–10%)** eller **ganska nöjda (70–90%)**, vilket tyder på en uppdelning i två grupper.
#
# - **Få extremt nöjda (100%)**, och viss spridning i mitten.
#
# - **HR bör analysera varför vissa är missnöjda** och vidta åtgärder för att förbättra trivsel och minska personalomsättning.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="salary", hue="left", data=df, palette="coolwarm")
plt.xlabel("Lönenivå", fontsize=12)
plt.ylabel("Antal Anställda", fontsize=12)
plt.title("Lönenivå och Personalomsättning", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# ### **Kort analys:**
#
# Diagrammet visar sambandet mellan lön och personalomsättning.
#
# - **Låg lön →** Hög personalomsättning: Många lågavlönade anställda lämnar företaget.
#
# - **Medellön →** Viss personalomsättning: Något färre slutar jämfört med låg-lönegruppen.
#
# - **Hög lön →** Låg personalomsättning: Få högavlönade anställda lämnar.

# %%
plt.figure(figsize=(8,5))

# Skapa linjediagram för att visa sambandet mellan senaste utvärdering och antal projekt
sns.lineplot(x="last_evaluation", y="number_project", data=df, marker="o", color="green", linewidth=2)

# Lägg till etiketter och titel
plt.xlabel("Senaste utvärdering", fontsize=12)
plt.ylabel("Antal projekt", fontsize=12)
plt.title("Samband mellan senaste utvärdering och antal projekt", fontsize=14, fontweight="bold")

# Visa diagrammet
plt.show()

# %% [markdown]
# ### **Kort analys:**
#
# Diagrammet visar sambandet mellan senaste utvärdering och antal projekt.
#
# - **Positiv trend:** Högre utvärderingsbetyg korrelerar med fler genomförda projekt.
#
# - **Dipp runt 45-50:** Möjlig indikation på lågpresterande eller missnöjda anställda.
#
# - **Variation vid låga betyg:** Större spridning i antal projekt när utvärderingen är låg.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="left", y="satisfaction_level", data=df, palette="coolwarm")
plt.xlabel("Personalomsättning", fontsize=12)
plt.ylabel("Arbetsnöjdhet", fontsize=12)
plt.title("Arbetsnöjdhet för Anställda som Lämnat vs Stannar", fontsize=14, fontweight="bold")
plt.show()
# Out:
# /var/folders/zh/q7sj6m_96t31rml8dzxc_6wr0000gn/T/ipykernel_647/1841547361.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="left", y="satisfaction_level", data=df, palette="coolwarm")

# %% [markdown]
# ### **Kort analys av diagrammet**
# - **Anställda som lämnat ("Left") har lägre arbetsnöjdhet** jämfört med de som stannat.
#
# - **De som stannat ("Stayed") har betydligt högre arbetsnöjdhet**, vilket tyder på att nöjdhet är en viktig faktor för att behålla personal.
#
# - **HR bör fokusera på att öka nöjdheten** för att minska personalomsättningen.

# %%
# Skapa en count plot för Work_accident vs Department
plt.figure(figsize=(12, 8))
sns.countplot(data=df_cleaned, x='Department', hue='Work_accident', palette='Set2')

# Lägg till etiketter och titel
plt.title("Fördelning av arbetsplatsolyckor per avdelning", fontsize=14)
plt.xlabel("Avdelning", fontsize=12)
plt.ylabel("Antal anställda med olyckor", fontsize=12)
plt.xticks(rotation=45)

# Visa diagrammet 
plt.show()

# %% [markdown]
# ### **Kort analys av diagrammet**
# Diagrammet visar fördelningen av arbetsplatsolyckor per avdelning, där:
#
# - Gröna staplar (No) representerar anställda utan olyckor.
#
# - Orange staplar (Yes) visar anställda som drabbats av olyckor.
#
# **Nyckelinsikter**
# - Högst antal olyckor: Sales och Technical har flest olyckor.
#
# - Färre olyckor i administrativa avdelningar: Accounting, HR och Management har låga olyckstal.
#
# - Alla avdelningar har viss olycksrisk, men andelen varierar.

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x=df["time_spend_company"], hue=df["salary"], palette="coolwarm")
plt.xlabel("Antal år på företaget", fontsize=12)
plt.ylabel("Antal anställda", fontsize=12)
plt.title("Antal anställda per lönenivå och erfarenhet", fontsize=14, fontweight="bold")
plt.legend(title="Lönenivå")
plt.show()

# %% [markdown]
# **Analys av diagrammet**
#
# Diagrammet visar antal anställda per lönenivå och antal år på företaget.
#
# Lönenivåer:
#
# - **Low (grå):** Flest anställda finns i denna kategori.
#
# - **Medium (orange):** Näst flest anställda.
#
# - **High (blå):** Få anställda i denna kategori.
#
# **Nyckelinsikter**
# - Flest anställda har 2–4 års erfarenhet.
#
# - Låg och medel lön dominerar, medan hög lön är ovanlig.
#
# - Ju längre erfarenhet, desto färre anställda.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Department", hue="salary", data=df, order=df["Department"].value_counts().index, palette="Set2")
plt.xticks(rotation=45)
plt.xlabel("Avdelning")
plt.ylabel("Antal anställda")
plt.title("Lönefördelning per avdelning")
plt.legend(title="Lön")
plt.show()

# %% [markdown]
# **Analys av diagrammet**
#
# Diagrammet visar lönefördelningen per avdelning i ett företag.
#
# - X-axeln representerar olika avdelningar (exempelvis sales, technical, support, IT, etc.).
#
# - Y-axeln visar antalet anställda i varje avdelning.
#
# **Färgerna representerar olika lönekategorier:**
#
# - Grön ("high") = Hög lön
#
# - Orange ("low") = Låg lön
#
# - Blå ("medium") = Medel lön
#
# **Snabb analys:**
# - Försäljningsavdelningen (sales) har flest anställda, och majoriteten har låg eller medel lön.
#
# - Tekniska, support och IT-avdelningarna har också många anställda, men fördelningen är mer balanserad.
#
# - Ledning (management) har relativt få anställda, men fler med hög lön jämfört med andra avdelningar.

# %%
# Räkna antal anställda per avdelning
print(df["Department"].value_counts())

# Räkna antal anställda i varje lönekategori
print(df["salary"].value_counts())
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
# 🔹 Executive Summary
summary = """
### 📌 Executive Summary

Efter att ha analyserat personaldata kan vi dra följande slutsatser:
- Anställda med fler år på företaget tenderar att ha högre lön.
- Arbetsnöjdheten varierar mellan avdelningar, vilket kan indikera att vissa arbetsmiljöer är bättre än andra.
- Personalomsättningen (Attrition) kan vara ett problem – det är viktigt att analysera varför anställda lämnar företaget.

🔹 **Rekommendation**:
1. Analysera avdelningar med låg arbetsnöjdhet och förbättra arbetsmiljön där.
2. Undersök orsakerna bakom personalomsättningen och ta fram strategier för att behålla anställda.
3. Granska lönefördelningen för att säkerställa rättvisa och motiverade löner.

"""
print(summary)
# Out:
# ### 📌 Executive Summary
#
# Efter att ha analyserat personaldata kan vi dra följande slutsatser:
# - Anställda med fler år på företaget tenderar att ha högre lön.
# - Arbetsnöjdheten varierar mellan avdelningar, vilket kan indikera att vissa arbetsmiljöer är bättre än andra.
# - Personalomsättningen (Attrition) kan vara ett problem – det är viktigt att analysera varför anställda lämnar företaget.
#
# 🔹 **Rekommendation**:
# 1. Analysera avdelningar med låg arbetsnöjdhet och förbättra arbetsmiljön där.
# 2. Undersök orsakerna bakom personalomsättningen och ta fram strategier för att behålla anställda.
# 3. Granska lönefördelningen för att säkerställa rättvisa och motiverade löner.

# %% [markdown]
# ### Självutvärdering
#
# **1. Vad har varit roligast i kunskapskontrollen?**
# Det roligaste har varit att arbeta med dataanalys och att skapa visualiseringar för att förstå datasetet bättre. Det var också intressant att se hur olika statistiska metoder kan användas för att dra slutsatser om personaldata.
#
# **2. Vilket betyg anser du att du ska ha och varför?**
# Jag anser att jag ska få VG eftersom jag har genomfört en djupgående analys, använt relevanta statistiska metoder och presenterat resultaten tydligt med visualiseringar. Jag har även motiverat mina slutsatser och rekommendationer på ett genomtänkt sätt.
#
# **3. Vad har varit mest utmanande i arbetet och hur har du hanterat det?**
# Den största utmaningen har varit att välja rätt analysmetoder för att få fram meningsfulla insikter ur datasetet. Det var ibland svårt att avgöra vilka visualiseringar som bäst representerar datan och hur resultaten ska tolkas på ett statistiskt korrekt sätt. Jag hanterade detta genom att läsa på om olika statistiska metoder, testa olika visualiseringar och jämföra resultaten innan jag drog slutsatser.
